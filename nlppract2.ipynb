# %% [markdown]
# <a href="https://colab.research.google.com/github/cs24dse016-design/CSL701-CS43_Machine-Learning-Lab/blob/main/nlppract2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Name;- Maruti Patil
# CE-35

# %%
get_ipython().system('pip install gtts')
from gtts import gTTS
from IPython.display import Audio
import os

text = input("Enter the text to convert into speech:")

tts = gTTS(text=text,lang='en')

filename = "speech.mp3"
tts.save(filename)
display(Audio(filename,autoplay = True))
# Out:
# ...
# Enter the text to convert into speech:Welcome to the nlp program
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# !apt-get -qq install ffmpeg
# !pip install pydub SpeechRecognition

from google.colab import files
from pydub import AudioSegment
import speech_recognition as sr

# Upload file
uploaded = files.upload()
filename = list(uploaded.keys())[0]

# Convert MP3 to WAV if needed
if filename.endswith(".mp3"):
    sound = AudioSegment.from_mp3(filename)
    filename = "audio.wav"
    sound.export(filename, format="wav")

# Speech Recognition
r = sr.Recognizer()

with sr.AudioFile(filename) as source:
    audio = r.record(source)

try:
    text = r.recognize_google(audio)
    print("Recognized Text:\n")
    print(text)
except Exception as e:
    print("Error:", e)
# Out:
# ...
# /usr/local/lib/python3.12/dist-packages/pydub/utils.py:300: SyntaxWarning: invalid escape sequence '\('
#   m = re.match('([su]([0-9]{1,2})p?) \(([0-9]{1,2}) bit\)$', token)
# /usr/local/lib/python3.12/dist-packages/pydub/utils.py:301: SyntaxWarning: invalid escape sequence '\('
#   m2 = re.match('([su]([0-9]{1,2})p?)( \(default\))?$', token)
# /usr/local/lib/python3.12/dist-packages/pydub/utils.py:310: SyntaxWarning: invalid escape sequence '\('
#   elif re.match('(flt)p?( \(default\))?$', token):
# /usr/local/lib/python3.12/dist-packages/pydub/utils.py:314: SyntaxWarning: invalid escape sequence '\('
#   elif re.match('(dbl)p?( \(default\))?$', token):
#      <input type="file" id="files-3c19fff3-ac2e-4649-8c90-7b491646e29b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3c19fff3-ac2e-4649-8c90-7b491646e29b">
#       Upload widget is only available when the cell has been executed in the
# ...
